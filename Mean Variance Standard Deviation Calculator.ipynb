# %% [markdown]
# Create a function named calculate() in mean_var_std.py that uses Numpy to output the mean, variance, standard deviation, max, min, and sum of the rows, columns, and elements in a 3 x 3 matrix.
#
# The input of the function should be a list containing 9 digits. The function should convert the list into a 3 x 3 Numpy array, and then return a dictionary containing the mean, variance, standard deviation, max, min, and sum along both axes and for the flattened matrix.
#
# The returned dictionary should follow this format:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# If a list containing less than 9 elements is passed into the function, it should raise a ValueError exception with the message: "List must contain nine numbers." The values in the returned dictionary should be lists and not Numpy arrays.
#
# For example, calculate([0,1,2,3,4,5,6,7,8]) should return:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np

def calculate(list):
    if len(list)!=9:
        raise ValueError("List must contain nine numbers.")
        
    arr=np.array(list).reshape(3,3)
    mean_columns=[arr[:,0].mean(), arr[:,1].mean(),arr[:,2].mean()]
    mean_rows=[arr[0].mean(), arr[1].mean(),arr[2].mean()]
    mean_arr=arr.mean()

    var_columns=[arr[:,0].var(), arr[:,1].var(), arr[:,2].var()]
    var_rows=[arr[0].var(), arr[1].var(),arr[2].var()]
    var_arr=arr.var()

    std_columns=[arr[:,0].std(), arr[:,1].std(), arr[:,2].std()]
    std_rows=[arr[0].std(), arr[1].std(),arr[2].std()]
    std_arr=arr.std()

    max_columns=[arr[:,0].max(), arr[:,1].max(), arr[:,2].max()]
    max_rows=[arr[0].max(), arr[1].max(), arr[2].max()]
    max_arr=arr.max()

    min_columns=[arr[:,0].min(), arr[:,1].min(), arr[:,2].min()]
    min_rows=[arr[0].min(), arr[1].min(), arr[2].min()]
    min_arr=arr.min()

    sum_columns=[arr[:,0].sum(), arr[:,1].sum(), arr[:,2].sum()]
    sum_rows=[arr[0].sum(), arr[1].sum(), arr[2].sum()]
    sum_arr=arr.sum()

    return {
              'mean': [mean_columns, mean_rows, mean_arr],
              'variance': [var_columns, var_rows, var_arr],
              'standard deviation': [std_columns, std_rows, std_arr],
              'max': [max_columns, max_rows, max_arr],
              'min': [min_columns, min_rows, min_arr],
              'sum': [sum_columns, sum_rows, sum_arr]
    }

# %%
#To check the solution of the exercise we will use the array of the problem
ls=[0,1,2,3,4,5,6,7,8]

# %%
calculate(ls)
# Out:
# {'mean': [[3.0, 4.0, 5.0], [1.0, 4.0, 7.0], 4.0],
#  'variance': [[6.0, 6.0, 6.0],
#   [0.6666666666666666, 0.6666666666666666, 0.6666666666666666],
#   6.666666666666667],
#  'standard deviation': [[2.449489742783178,
#    2.449489742783178,
#    2.449489742783178],
#   [0.816496580927726, 0.816496580927726, 0.816496580927726],
#   2.581988897471611],
#  'max': [[6, 7, 8], [2, 5, 8], 8],
#  'min': [[0, 1, 2], [0, 3, 6], 0],
#  'sum': [[9, 12, 15], [3, 12, 21], 36]}

# %%
#To prove in other cases
ls=[i for i in range (8)]
calculate(ls)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-142-cd2a4b712e46> in <module>
#       1 #To prove in other cases
#       2 ls=[i for i in range (8)]
# ----> 3 calculate(ls)
#
# <ipython-input-139-c087eceacd1d> in calculate(list)
#       3 def calculate(list):
#       4     if len(list)!=9:
# ----> 5         raise ValueError("List must contain nine numbers.")
#       6
#       7     arr=np.array(list).reshape(3,3)
#
# ValueError: List must contain nine numbers.

# %%
import random
ls = [random.randint(0,10) for i in range(9)]
calculate(ls)
# Out:
# {'mean': [[0.6666666666666666, 3.0, 6.666666666666667],
#   [3.6666666666666665, 2.6666666666666665, 4.0],
#   3.4444444444444446],
#  'variance': [[0.22222222222222224, 2.6666666666666665, 0.888888888888889],
#   [6.888888888888889, 5.555555555555556, 8.666666666666666],
#   7.358024691358025],
#  'standard deviation': [[0.4714045207910317,
#    1.632993161855452,
#    0.9428090415820634],
#   [2.6246692913372702, 2.3570226039551585, 2.943920288775949],
#   2.7125679146074897],
#  'max': [[1, 5, 8], [6, 6, 8], 8],
#  'min': [[0, 1, 6], [0, 1, 1], 0],
#  'sum': [[2, 9, 20], [11, 8, 12], 31]}
