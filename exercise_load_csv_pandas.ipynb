# %% [markdown]
# -Lea y almacene en un DataFrame de películas con los datos del archivo "movies.csv"
#
# -Eche un vistazo al archivo antes de leerlo en un DataFrame y vea lo que será necesario para analizarlo correctamente.
#
# - Utiliza el separador adecuado.✔
# - Los datos dados no tienen una cabecera definida. Utilice los nombres de las columnas indicados en la variable column_names.✔
# - Omita las 3 primeras filas.✔
# - Los valores que faltan se codifican como caracteres `?`. Analice esos valores como objetos `NaN`.✔
# - La columna `buget` tiene comas que separan los miles, asegúrese de que la columna es de tipo de datos flotante.✔
# - El índice del DataFrame debe ser representado por la columna `movie_title`.
#
# Lea y almacene en un DataFrame `movies` y guárdalo como csv.

# %%
column_names = ['color', 'director_name', 'num_critic_for_reviews', 'duration',
                'gross', 'movie_title', 'num_user_for_reviews', 'country',
                'cotent_rating', 'budget', 'title_year', 'imdb_score', 'genre']

# %%
filepath = "data/movies.csv"

with open(filepath, 'r') as reader:
    for index, line in enumerate(reader.readlines()):
        # read just the first 10 lines
        if (index < 10):
            print(index, line)
# Out:
# 0 Color|James Cameron|723.0|178.0|760505847.0|AvatarÂ |3054.0|USA|PG-13|237,000,000.0|2009.0|7.9|Action
#
# 1 Color|Gore Verbinski|302.0|169.0|309404152.0|Pirates of the Caribbean: At World's EndÂ |1238.0|USA|PG-13|300,000,000.0|2007.0|7.1|Action
#
# 2 Color|Sam Mendes|602.0|148.0|200074175.0|SpectreÂ |994.0|UK|PG-13|245,000,000.0|2015.0|6.8|Action
#
# 3 Color|Christopher Nolan|813.0|164.0|448130642.0|The Dark Knight RisesÂ |2701.0|USA|PG-13|250,000,000.0|2012.0|8.5|Action
#
# 4 ?|Doug Walker|?|?|?|Star Wars: Episode VII - The Force AwakensÂ             |?|?|?|?|?|7.1|Documentary
#
# 5 Color|Andrew Stanton|462.0|132.0|73058679.0|John CarterÂ |738.0|USA|PG-13|263,700,000.0|2012.0|6.6|Action
#
# 6 Color|Sam Raimi|392.0|156.0|336530303.0|Spider-Man 3Â |1902.0|USA|PG-13|258,000,000.0|2007.0|6.2|Action
#
# 7 Color|Nathan Greno|324.0|100.0|200807262.0|TangledÂ |387.0|USA|PG|260,000,000.0|2010.0|7.8|Adventure
#
# ...

# %%
import pandas as pd
movies=pd.read_csv("data/movies.csv",sep="|",header=None,names=column_names, skiprows=[1,3], na_values=[ '?'], thousands=',',index_col="movie_title")
movies
# Out:
#                                                     color      director_name  \
# movie_title
# Avatar                                              Color      James Cameron
# Spectre                                             Color         Sam Mendes
# Star Wars: Episode VII - The Force Awakens     ...    NaN        Doug Walker
# John Carter                                         Color     Andrew Stanton
# Spider-Man 3                                        Color          Sam Raimi
# ...                                                   ...                ...
# Guardians of the Galaxy                             Color         James Gunn
# Interstellar                                        Color  Christopher Nolan
# Inception                                           Color  Christopher Nolan
# Godzilla Resurgence                                 Color       Hideaki Anno
# The Hobbit: An Unexpected Journey                   Color      Peter Jackson
#
# ...

# %%
movies.budget #it's float64
# Out:
# movie_title
# Avatar                                                     237000000.0
# Spectre                                                    245000000.0
# Star Wars: Episode VII - The Force Awakens                         NaN
# John Carter                                                263700000.0
# Spider-Man 3                                               258000000.0
#                                                               ...
# Guardians of the Galaxy                                    170000000.0
# Interstellar                                               165000000.0
# Inception                                                  160000000.0
# Godzilla Resurgence                                                NaN
# The Hobbit: An Unexpected Journey                          180000000.0
# Name: budget, Length: 98, dtype: float64

# %%
#movies.to_csv('out.csv',index=None)
